# %% [markdown]
# # Amazon Scrape

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from sqlalchemy import create_engine


url_str = input("Enter the product you want to search: ")
url = []

words = url_str.split()
var = len(words)


# url = "https://www.amazon.com/s/ref=nb_sb_noss_1?url=search-alias%3Daps&field-keywords=iphone%208"
# Out:
# Enter the product you want to search for: iphone 8

# %%
if var == 1:
    url = "https://www.amazon.com/s/ref=nb_sb_noss_1?url=search-alias%3Daps&field-keywords=" + words[0]

if var == 2:
    url = "https://www.amazon.com/s/ref=nb_sb_noss_1?url=search-alias%3Daps&field-keywords=" + words[0] + "+" + words[1]

elif var == 3:
    url = "https://www.amazon.com/s/ref=nb_sb_noss_1?url=search-alias%3Daps&field-keywords=" + words[0] + "+" + words[1] + "+" + words[2]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html'}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.content, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="//images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="//m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="//completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
results = soup.find_all('div', class_="s-include-content-margin s-border-bottom")
results
# Out:
# [<div class="s-include-content-margin s-border-bottom">
#  <div class="a-section a-spacing-medium">
#  <div class="sg-row">
#  <div class="a-section a-spacing-micro s-min-height-small">
#  </div>
#  </div>
#  <div class="sg-row">
#  <div class="sg-col-4-of-24 sg-col-4-of-12 sg-col-4-of-36 sg-col-4-of-28 sg-col-4-of-16 sg-col sg-col-4-of-20 sg-col-4-of-32"><div class="sg-col-inner">
#  <div class="a-section a-spacing-none">
#  <span class="rush-component" data-component-type="s-product-image">
#  <a class="a-link-normal" href="/Apple-iPhone-GSM-Unlocked-64GB/dp/B077583FPX">
#  <div class="a-section aok-relative s-image-fixed-height">
# ...

# %%
product=[]
price=[]
review=[]

for page in range(1,500):

    for result in results:
        try:
            product_name = result.find('span', class_="a-size-medium a-color-base a-text-normal").text
            price_whole = result.find('span',class_='a-price-whole').text
            price_fraction = result.find('span',class_='a-price-fraction').text
            reviews = result.find('span',class_='a-icon-alt').text
       

            if (product_name and price_whole and price_fraction):
                product.append(product_name)
                price.append(price_whole + price_fraction)
                review.append(reviews)
          
        except AttributeError as e:
            print(e)

# %%
amazon = {"Product_Name":product,"Price":price,"Rating":review}

amazon_df=pd.DataFrame(amazon)

amazon_df
# Out:
#                                            Product_Name   Price  \
# 0     Apple iPhone 8, 64GB, Space Gray - for AT&T/T-...  346.99
# 1     Apple iPhone 8, GSM Unlocked, 64GB - Gold (Ren...  349.00
# 2     Apple iPhone 7, 32GB, Rose Gold - For AT&T (Re...  184.99
# 3     Apple iPhone 8 a1905 64GB LTE GSM Unlocked (Re...  355.00
# 4     Apple iPhone XR, 64GB, Blue - Fully Unlocked (...  569.67
# 5     Apple iPhone 8 Plus Fully Unlocked 256GB Space...  549.99
# 6     Apple iPhone 8 4.7", 256 GB, Fully Unlocked, S...  389.99
# 7     Apple iPhone 6S, 16GB, Rose Gold - For AT&T / ...  136.99
# 8     Apple iPhone 8 256GB GSM Unlocked Phone, Gold ...  404.99
# 9     Apple iPhone 8 Plus 64GB Unlocked GSM Phone - ...  469.99
# 10    Apple iPhone 8 64GB GSM Unlocked Smartphone, R...  355.00
# 11    Apple iPhone 7, 32GB, Rose Gold - For Verizon ...  239.99
# 12      Apple iPhone 8, CDMA Unlocked, 64GB - (Renewed)  374.99
# 13    Apple iPhone 8 Plus, GSM Unlocked, 256GB - Spa...  519.00
# ...

# %%
amazon_df["Product_Name"]=amazon_df["Product_Name"].str.split("iPhone 7",n=1,expand=True)
amazon_df
# Out:
#                                            Product_Name   Price  \
# 0     Apple iPhone 8, 64GB, Space Gray - for AT&T/T-...  346.99
# 1     Apple iPhone 8, GSM Unlocked, 64GB - Gold (Ren...  349.00
# 2                                                Apple   184.99
# 3     Apple iPhone 8 a1905 64GB LTE GSM Unlocked (Re...  355.00
# 4     Apple iPhone XR, 64GB, Blue - Fully Unlocked (...  569.67
# 5     Apple iPhone 8 Plus Fully Unlocked 256GB Space...  549.99
# 6     Apple iPhone 8 4.7", 256 GB, Fully Unlocked, S...  389.99
# 7     Apple iPhone 6S, 16GB, Rose Gold - For AT&T / ...  136.99
# 8     Apple iPhone 8 256GB GSM Unlocked Phone, Gold ...  404.99
# 9     Apple iPhone 8 Plus 64GB Unlocked GSM Phone - ...  469.99
# 10    Apple iPhone 8 64GB GSM Unlocked Smartphone, R...  355.00
# 11                                               Apple   239.99
# 12      Apple iPhone 8, CDMA Unlocked, 64GB - (Renewed)  374.99
# 13    Apple iPhone 8 Plus, GSM Unlocked, 256GB - Spa...  519.00
# ...

# %%
amazon_df["Product_Name"]=amazon_df["Product_Name"].str.split("iPhone 6",n=1,expand=True)
amazon_df
# Out:
#                                            Product_Name   Price  \
# 0     Apple iPhone 8, 64GB, Space Gray - for AT&T/T-...  346.99
# 1     Apple iPhone 8, GSM Unlocked, 64GB - Gold (Ren...  349.00
# 2                                                Apple   184.99
# 3     Apple iPhone 8 a1905 64GB LTE GSM Unlocked (Re...  355.00
# 4     Apple iPhone XR, 64GB, Blue - Fully Unlocked (...  569.67
# 5     Apple iPhone 8 Plus Fully Unlocked 256GB Space...  549.99
# 6     Apple iPhone 8 4.7", 256 GB, Fully Unlocked, S...  389.99
# 7                                                Apple   136.99
# 8     Apple iPhone 8 256GB GSM Unlocked Phone, Gold ...  404.99
# 9     Apple iPhone 8 Plus 64GB Unlocked GSM Phone - ...  469.99
# 10    Apple iPhone 8 64GB GSM Unlocked Smartphone, R...  355.00
# 11                                               Apple   239.99
# 12      Apple iPhone 8, CDMA Unlocked, 64GB - (Renewed)  374.99
# 13    Apple iPhone 8 Plus, GSM Unlocked, 256GB - Spa...  519.00
# ...

# %%
amazon_df["Product_Name"]=amazon_df["Product_Name"].str.split("iPhone 10",n=1,expand=True)
amazon_df
# Out:
#                                            Product_Name   Price  \
# 0     Apple iPhone 8, 64GB, Space Gray - for AT&T/T-...  346.99
# 1     Apple iPhone 8, GSM Unlocked, 64GB - Gold (Ren...  349.00
# 2                                                Apple   184.99
# 3     Apple iPhone 8 a1905 64GB LTE GSM Unlocked (Re...  355.00
# 4     Apple iPhone XR, 64GB, Blue - Fully Unlocked (...  569.67
# 5     Apple iPhone 8 Plus Fully Unlocked 256GB Space...  549.99
# 6     Apple iPhone 8 4.7", 256 GB, Fully Unlocked, S...  389.99
# 7                                                Apple   136.99
# 8     Apple iPhone 8 256GB GSM Unlocked Phone, Gold ...  404.99
# 9     Apple iPhone 8 Plus 64GB Unlocked GSM Phone - ...  469.99
# 10    Apple iPhone 8 64GB GSM Unlocked Smartphone, R...  355.00
# 11                                               Apple   239.99
# 12      Apple iPhone 8, CDMA Unlocked, 64GB - (Renewed)  374.99
# 13    Apple iPhone 8 Plus, GSM Unlocked, 256GB - Spa...  519.00
# ...

# %%
amazon_df=amazon_df[amazon_df['Product_Name'] != "Apple "]
amazon_df
# Out:
#                                            Product_Name   Price  \
# 0     Apple iPhone 8, 64GB, Space Gray - for AT&T/T-...  346.99
# 1     Apple iPhone 8, GSM Unlocked, 64GB - Gold (Ren...  349.00
# 3     Apple iPhone 8 a1905 64GB LTE GSM Unlocked (Re...  355.00
# 4     Apple iPhone XR, 64GB, Blue - Fully Unlocked (...  569.67
# 5     Apple iPhone 8 Plus Fully Unlocked 256GB Space...  549.99
# 6     Apple iPhone 8 4.7", 256 GB, Fully Unlocked, S...  389.99
# 8     Apple iPhone 8 256GB GSM Unlocked Phone, Gold ...  404.99
# 9     Apple iPhone 8 Plus 64GB Unlocked GSM Phone - ...  469.99
# 10    Apple iPhone 8 64GB GSM Unlocked Smartphone, R...  355.00
# 12      Apple iPhone 8, CDMA Unlocked, 64GB - (Renewed)  374.99
# 13    Apple iPhone 8 Plus, GSM Unlocked, 256GB - Spa...  519.00
# 14    Apple iPhone 8 4.7in, 64 GB, T-Mobile Only Spa...  359.99
# 16    Apple iPhone 8, 64GB, Space Gray - for AT&T/T-...  346.99
# 17    Apple iPhone 8, GSM Unlocked, 64GB - Gold (Ren...  349.00
# ...

# %%
amazon_df = amazon_df.rename(columns={"Product_Name": "product_name","Price": "price","Rating":"rating"})

# %%
connection_string = "postgres:postgres@localhost:5432/product_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['iphone_8']

# %%
amazon_df.to_sql(name='iphone_8', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     724         else:
# --> 725             cursor.executemany(statement, parameters)
#     726
#
# NotNullViolation: null value in column "id" violates not-null constraint
# DETAIL:  Failing row contains (null, Apple iPhone 8, 64GB, Space Gray - for AT&T/T-Mobile (Renewed), 346.99, 4.0 out of 5 stars).
#
#
# The above exception was the direct cause of the following exception:
#
# ...
